# %% [markdown]
# Tarea 1
# Listas

# %%
grades = [15, 18, 12, 20, 16]

# %%
print(grades)
# Out:
# [15, 18, 12, 20, 16]

# %%
grades.append(17)

# %%
grades.sort()

# %%
max(grades)
# Out:
# 20

# %%
min(grades)
# Out:
# 12

# %%
len(grades)
# Out:
# 6

# %%
print(grades)
# Out:
# [12, 15, 16, 17, 18, 20]
